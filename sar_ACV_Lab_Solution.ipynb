# %% [markdown]
# # Bounding box detection - Racoon data
#
#
# ## Data files
# - images_racoon.rar: contain images of racoons
# - train_labels.cv: contains coordinates for bounding box for every image

# %% [markdown]
# ### Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import cv2
from tensorflow.keras.applications.mobilenet import MobileNet, preprocess_input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
from tensorflow.keras.layers import Conv2D, Reshape
from tensorflow.keras.utils import Sequence
from tensorflow.keras.backend import epsilon

# %% [markdown]
# ### Change directory

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
codepath = '/gdrive/My Drive/Colab Notebooks/ACV_Assignments'
import os
os.chdir(codepath)
# !pwd
# !ls -l
# Out:
# /gdrive/My Drive/Colab Notebooks/ACV_Assignments
# total 26400
# -rw------- 1 root root 26574193 Sep  7 18:21  images_racoon.rar
# -rw------- 1 root root   226107 Sep 17 03:39 'R9 - ACV - Internal_Lab_Solution.ipynb'
# -rw------- 1 root root   224149 Oct 28 14:51  sar_ACV_Lab_Solution.ipynb
# -rw------- 1 root root     7913 Sep  7 18:20  train_labels.csv

# %% [markdown]
# ### Load the training data from train.csv file

# %%
df = pd.read_csv("train_labels.csv")

# %% [markdown]
# ### Print the shape of the train dataset

# %%
df.shape
# Out:
# (173, 8)

# %%
df.head()
# Out:
#          filename  width  height    class  xmin  ymin  xmax  ymax
# 0  raccoon-17.jpg    259     194  raccoon    95    60   167   118
# 1  raccoon-11.jpg    660     432  raccoon     3     1   461   431
# 2  raccoon-63.jpg    600     400  raccoon    74   107   280   290
# 3  raccoon-63.jpg    600     400  raccoon   227    93   403   298
# 4  raccoon-60.jpg    273     185  raccoon    58    33   197   127

# %% [markdown]
# ### Declare a variable IMAGE_SIZE = 128 as we will be using MobileNet which will be taking Input shape as 128 * 128

# %%
IMAGE_SIZE =128

# %% [markdown]
# ### With the help of csv.reader write a for loop which can load the train.csv file and store the path, width, height, x0,y0,x1,y1 in induvidual variables. <br>
# 1. Create a list variable known as 'path' which has all the path for all the training images
# 2. Create an array 'coords' which has the resized coordinates of the bounding box for the training images
#
# <u>Note:</u> All the training images should be downsampled to 128 * 128 as it is the input shape of MobileNet (which we will be using for Object detection). Hence the corresponding coordinates of the bounding boxes should be changed to match the image dimension of 128 * 128

# %%
path = '/gdrive/My Drive/Colab Notebooks/ACV_Assignments/images_racoon'

# %%
# !pwd
# Out:
# /gdrive/My Drive/Colab Notebooks/ACV_Assignments

# %%
import csv

# %%
with open('train_labels.csv','r') as csvfile:
    paths = []
    coords = np.zeros((sum(1 for line in csvfile) - 1, 4))
    spamreader = csv.reader(csvfile, delimiter=',')
    csvfile.seek(0)
    next(spamreader, None)
    for i,row in enumerate(spamreader):
        #print(row)
        for j, r in enumerate(row): # Parse row with seven entities
            #print(i)
            if((j!= 0) & (j!=3)):
                row[j] = int(r)
            
        #print(row)      
        path, width, height, class_, xmin, ymin, xmax, ymax = row
        paths.append(path)
        #print(i)
        coords[i,0] = xmin * IMAGE_SIZE / width
        coords[i,1] = ymin * IMAGE_SIZE / height
        coords[i,2] = xmax * IMAGE_SIZE / width # Normalize bounding box by image size
        coords[i,3] = ymax * IMAGE_SIZE / height

# %% [markdown]
# ### Write a for loop which can load all the training images into a variable 'batch_images' using the paths from the 'paths' variable
# <u>Note:</u> Convert the image to RGB scale as the MobileNet accepts 3 channels as inputs

# %%
from PIL import Image
batch_images = np.zeros((len(paths), IMAGE_SIZE, IMAGE_SIZE, 3), dtype=np.float32)
for i, fil in enumerate(paths):
    print(i, fil)
    img = Image.open('images_racoon/images/images/'+fil)
    img = img.resize((IMAGE_SIZE, IMAGE_SIZE))
    img = img.convert('RGB')
    batch_images[i] = preprocess_input(np.array(img, dtype=np.float32))
# Out:
# 0 raccoon-17.jpg
# 1 raccoon-11.jpg
# 2 raccoon-63.jpg
# 3 raccoon-63.jpg
# 4 raccoon-60.jpg
# 5 raccoon-69.jpg
# 6 raccoon-180.jpg
# 7 raccoon-200.jpg
# 8 raccoon-141.jpg
# 9 raccoon-19.jpg
# 10 raccoon-84.jpg
# 11 raccoon-124.jpg
# 12 raccoon-182.jpg
# 13 raccoon-111.jpg
# 14 raccoon-91.jpg
# 15 raccoon-79.jpg
# 16 raccoon-93.jpg
# 17 raccoon-20.jpg
# 18 raccoon-42.jpg
# 19 raccoon-139.jpg
# 20 raccoon-58.jpg
# 21 raccoon-71.jpg
# 22 raccoon-183.jpg
# 23 raccoon-1.jpg
# 24 raccoon-169.jpg
# 25 raccoon-82.jpg
# 26 raccoon-4.jpg
# 27 raccoon-101.jpg
# 28 raccoon-10.jpg
# 29 raccoon-166.jpg
# 30 raccoon-184.jpg
# 31 raccoon-38.jpg
# 32 raccoon-120.jpg
# 33 raccoon-142.jpg
# 34 raccoon-149.jpg
# 35 raccoon-51.jpg
# 36 raccoon-43.jpg
# 37 raccoon-123.jpg
# 38 raccoon-66.jpg
# 39 raccoon-9.jpg
# 40 raccoon-178.jpg
# 41 raccoon-47.jpg
# 42 raccoon-167.jpg
# 43 raccoon-54.jpg
# 44 raccoon-77.jpg
# 45 raccoon-155.jpg
# 46 raccoon-89.jpg
# 47 raccoon-153.jpg
# 48 raccoon-179.jpg
# 49 raccoon-115.jpg
# 50 raccoon-64.jpg
# 51 raccoon-56.jpg
# 52 raccoon-44.jpg
# 53 raccoon-39.jpg
# 54 raccoon-26.jpg
# 55 raccoon-162.jpg
# 56 raccoon-170.jpg
# 57 raccoon-187.jpg
# 58 raccoon-131.jpg
# 59 raccoon-174.jpg
# 60 raccoon-92.jpg
# 61 raccoon-193.jpg
# 62 raccoon-138.jpg
# 63 raccoon-157.jpg
# 64 raccoon-108.jpg
# 65 raccoon-116.jpg
# 66 raccoon-117.jpg
# 67 raccoon-117.jpg
# 68 raccoon-12.jpg
# 69 raccoon-12.jpg
# 70 raccoon-16.jpg
# 71 raccoon-90.jpg
# 72 raccoon-160.jpg
# 73 raccoon-75.jpg
# 74 raccoon-199.jpg
# 75 raccoon-97.jpg
# 76 raccoon-188.jpg
# 77 raccoon-21.jpg
# 78 raccoon-35.jpg
# 79 raccoon-85.jpg
# 80 raccoon-49.jpg
# 81 raccoon-86.jpg
# 82 raccoon-34.jpg
# 83 raccoon-196.jpg
# 84 raccoon-96.jpg
# 85 raccoon-3.jpg
# 86 raccoon-2.jpg
# 87 raccoon-52.jpg
# 88 raccoon-81.jpg
# 89 raccoon-112.jpg
# 90 raccoon-18.jpg
# 91 raccoon-94.jpg
# 92 raccoon-98.jpg
# 93 raccoon-83.jpg
# 94 raccoon-36.jpg
# 95 raccoon-24.jpg
# 96 raccoon-24.jpg
# 97 raccoon-195.jpg
# 98 raccoon-55.jpg
# 99 raccoon-55.jpg
# 100 raccoon-175.jpg
# 101 raccoon-163.jpg
# 102 raccoon-48.jpg
# 103 raccoon-70.jpg
# 104 raccoon-119.jpg
# 105 raccoon-119.jpg
# 106 raccoon-119.jpg
# 107 raccoon-88.jpg
# 108 raccoon-61.jpg
# 109 raccoon-61.jpg
# 110 raccoon-121.jpg
# 111 raccoon-74.jpg
# 112 raccoon-133.jpg
# 113 raccoon-177.jpg
# 114 raccoon-177.jpg
# 115 raccoon-159.jpg
# 116 raccoon-53.jpg
# 117 raccoon-132.jpg
# 118 raccoon-198.jpg
# 119 raccoon-198.jpg
# 120 raccoon-103.jpg
# 121 raccoon-46.jpg
# 122 raccoon-50.jpg
# 123 raccoon-37.jpg
# 124 raccoon-161.jpg
# 125 raccoon-194.jpg
# 126 raccoon-32.jpg
# 127 raccoon-15.jpg
# 128 raccoon-147.jpg
# 129 raccoon-151.jpg
# 130 raccoon-80.jpg
# 131 raccoon-6.jpg
# 132 raccoon-154.jpg
# 133 raccoon-135.jpg
# 134 raccoon-118.jpg
# 135 raccoon-150.jpg
# 136 raccoon-102.jpg
# 137 raccoon-130.jpg
# 138 raccoon-130.jpg
# 139 raccoon-7.jpg
# 140 raccoon-107.jpg
# 141 raccoon-173.jpg
# 142 raccoon-165.jpg
# 143 raccoon-25.jpg
# 144 raccoon-67.jpg
# 145 raccoon-13.jpg
# 146 raccoon-191.jpg
# 147 raccoon-45.jpg
# 148 raccoon-31.jpg
# 149 raccoon-31.jpg
# 150 raccoon-172.jpg
# 151 raccoon-100.jpg
# 152 raccoon-148.jpg
# 153 raccoon-148.jpg
# 154 raccoon-23.jpg
# 155 raccoon-30.jpg
# 156 raccoon-33.jpg
# 157 raccoon-136.jpg
# 158 raccoon-114.jpg
# 159 raccoon-76.jpg
# 160 raccoon-104.jpg
# 161 raccoon-109.jpg
# 162 raccoon-87.jpg
# 163 raccoon-113.jpg
# 164 raccoon-78.jpg
# 165 raccoon-65.jpg
# 166 raccoon-122.jpg
# 167 raccoon-73.jpg
# 168 raccoon-137.jpg
# 169 raccoon-171.jpg
# 170 raccoon-190.jpg
# 171 raccoon-22.jpg
# 172 raccoon-152.jpg

# %%
from tensorflow.keras.models import Model

# %% [markdown]
# ### Import MobileNet and load MobileNet into a variable named 'model' which takes input shape of 128 * 128 * 3. Freeze all the layers. Add convolution and reshape layers at the end to ensure the output is 4 coordinates

# %%
model = MobileNet(input_shape=(128, 128, 3), include_top=False) 
for layer in model.layers:
    layer.trainable = False
model1 = model.layers[-1].output
model1 = Conv2D(4, kernel_size=4)(model1)
model1 = Reshape((4,))(model1)

myModel = Model(inputs=model.input,outputs = model1)

# %% [markdown]
# ### Define a custom loss function IoU which calculates Intersection Over Union

# %%
import tensorflow as tf

# %%
def loss(gt,pred):
    intersections = 0
    unions = 0
    diff_width = np.minimum(gt[:,0] + gt[:,2], pred[:,0] + pred[:,2]) - np.maximum(gt[:,0], pred[:,0])
    diff_height = np.minimum(gt[:,1] + gt[:,3], pred[:,1] + pred[:,3]) - np.maximum(gt[:,1], pred[:,1])
    intersection = diff_width * diff_height
    
    # Compute union
    area_gt = gt[:,2] * gt[:,3]
    area_pred = pred[:,2] * pred[:,3]
    union = area_gt + area_pred - intersection

#     Compute intersection and union over multiple boxes
    for j, _ in enumerate(union):
        if union[j] > 0 and intersection[j] > 0 and union[j] >= intersection[j]:
            intersections += intersection[j]
            unions += union[j]

    # Compute IOU. Use epsilon to prevent division by zero
    iou = np.round(intersections / (unions + epsilon()), 4)
    iou = iou.astype(np.float32)
    return iou

def IoU(y_true, y_pred):
    iou = tf.py_function(loss, [y_true, y_pred], tf.float32)
    return iou

# %% [markdown]
# ### Write model.compile function & model.fit function with: <br>
# 1. Optimizer = Adam, Loss = 'mse' and metrics = IoU
# 2. Epochs = 30, batch_size = 32, verbose = 1

# %%
myModel.compile(loss="mean_squared_error", optimizer="Adam", metrics=IoU)
myModel.fit(batch_images, coords, epochs=30,
                    batch_size = 32,                                      
                    workers=7,
                    use_multiprocessing=True,
                    shuffle=True,
                    verbose=1)
# Out:
# Epoch 1/30
# 6/6 [==============================] - 2s 318ms/step - loss: 3995.4463 - IoU: 0.0880
# Epoch 2/30
# 6/6 [==============================] - 2s 317ms/step - loss: 722.9636 - IoU: 0.4348
# Epoch 3/30
# 6/6 [==============================] - 2s 316ms/step - loss: 474.5099 - IoU: 0.5764
# Epoch 4/30
# 6/6 [==============================] - 2s 319ms/step - loss: 606.9553 - IoU: 0.5286
# Epoch 5/30
# 6/6 [==============================] - 2s 320ms/step - loss: 326.8586 - IoU: 0.6225
# Epoch 6/30
# 6/6 [==============================] - 2s 317ms/step - loss: 198.0853 - IoU: 0.6516
# Epoch 7/30
# 6/6 [==============================] - 2s 313ms/step - loss: 199.6825 - IoU: 0.6493
# Epoch 8/30
# 6/6 [==============================] - 2s 316ms/step - loss: 160.5208 - IoU: 0.6921
# Epoch 9/30
# 6/6 [==============================] - 2s 318ms/step - loss: 121.7414 - IoU: 0.7487
# Epoch 10/30
# 6/6 [==============================] - 2s 316ms/step - loss: 114.4852 - IoU: 0.7638
# Epoch 11/30
# 6/6 [==============================] - 2s 317ms/step - loss: 101.5079 - IoU: 0.7722
# Epoch 12/30
# 6/6 [==============================] - 2s 315ms/step - loss: 88.9631 - IoU: 0.7818
# Epoch 13/30
# 6/6 [==============================] - 2s 320ms/step - loss: 83.5811 - IoU: 0.7886
# Epoch 14/30
# 6/6 [==============================] - 2s 324ms/step - loss: 77.3271 - IoU: 0.8115
# Epoch 15/30
# 6/6 [==============================] - 2s 319ms/step - loss: 72.9557 - IoU: 0.8164
# Epoch 16/30
# 6/6 [==============================] - 2s 316ms/step - loss: 71.1993 - IoU: 0.8236
# Epoch 17/30
# 6/6 [==============================] - 2s 320ms/step - loss: 67.2278 - IoU: 0.8230
# Epoch 18/30
# 6/6 [==============================] - 2s 318ms/step - loss: 63.9332 - IoU: 0.8201
# Epoch 19/30
# 6/6 [==============================] - 2s 323ms/step - loss: 62.7130 - IoU: 0.8386
# Epoch 20/30
# 6/6 [==============================] - 2s 318ms/step - loss: 61.1395 - IoU: 0.8418
# Epoch 21/30
# 6/6 [==============================] - 2s 317ms/step - loss: 59.1826 - IoU: 0.8498
# Epoch 22/30
# 6/6 [==============================] - 2s 315ms/step - loss: 58.6471 - IoU: 0.8450
# Epoch 23/30
# 6/6 [==============================] - 2s 318ms/step - loss: 57.0895 - IoU: 0.8574
# Epoch 24/30
# 6/6 [==============================] - 2s 317ms/step - loss: 55.3489 - IoU: 0.8577
# Epoch 25/30
# 6/6 [==============================] - 2s 319ms/step - loss: 54.6290 - IoU: 0.8581
# Epoch 26/30
# 6/6 [==============================] - 2s 319ms/step - loss: 53.9654 - IoU: 0.8598
# Epoch 27/30
# 6/6 [==============================] - 2s 319ms/step - loss: 53.4613 - IoU: 0.8634
# Epoch 28/30
# 6/6 [==============================] - 2s 323ms/step - loss: 52.3408 - IoU: 0.8679
# Epoch 29/30
# 6/6 [==============================] - 2s 320ms/step - loss: 53.5784 - IoU: 0.8634
# Epoch 30/30
# 6/6 [==============================] - 2s 318ms/step - loss: 52.4316 - IoU: 0.8536

# %% [markdown]
# ### Pick a test image from the given data

# %%
test_img = '//gdrive/My Drive/Colab Notebooks/ACV_Assignments/images_racoon/images/images/raccoon-154.jpg'
unscaled = cv2.imread(test_img)

# %% [markdown]
# ### Resize the image to 128 * 128 and preprocess the image for the MobileNet model

# %%
img_ht , img_wd, chnl = unscaled.shape
image = cv2.resize(unscaled,(IMAGE_SIZE,IMAGE_SIZE))
feat_scaled = preprocess_input(np.array(image,dtype=np.float32))

# %% [markdown]
# ### Predict the coordinates of the bounding box for the given test image

# %%
region = myModel.predict(x=np.array([feat_scaled]))[0]

# %% [markdown]
# ### Plot the test image using .imshow and draw a boundary box around the image with the coordinates obtained from the model

# %%
x0 = int(region[0] * img_wd / IMAGE_SIZE) # Scale the BBox
y0 = int(region[1] * img_ht / IMAGE_SIZE)

x1 = int((region[2]) * img_wd / IMAGE_SIZE)
y1 = int((region[3]) * img_ht / IMAGE_SIZE)


import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np


# Create figure and axes
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(unscaled)

# Create a Rectangle patch
rect = patches.Rectangle((x0, y0), (x1 - x0) , (y1 - y0) , linewidth=2, edgecolor='r', facecolor='none')

# Add the patch to the Axes
ax.add_patch(rect)

plt.show()
